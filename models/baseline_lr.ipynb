# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score

# %%
npz = np.load("../data_process/processed_fe/X_train_proc_fe.npz")
print("Keys inside this npz file:")
print(npz.files)
# Out:
# Keys inside this npz file:
# ['indices', 'indptr', 'format', 'shape', 'data']

# %%
import numpy as np
from scipy.sparse import load_npz

# 注意：用 load_npz 来加载稀疏矩阵！
X_train = load_npz("../data_process/processed_fe/X_train_proc_fe.npz")
X_valid = load_npz("../data_process/processed_fe/X_valid_proc_fe.npz")
X_test  = load_npz("../data_process/processed_fe/X_test_proc_fe.npz")

y_train = np.load("../data_process/processed_fe/y_train_fe.npy")
y_valid = np.load("../data_process/processed_fe/y_valid_fe.npy")

print("Train shape:", X_train.shape)
print("Valid shape:", X_valid.shape)
print("Test shape:", X_test.shape)

print("Type of X_train:", type(X_train))
# Out:
# Train shape: (475195, 67)
# Valid shape: (118799, 67)
# Test shape: (254569, 67)
# Type of X_train: <class 'scipy.sparse._csr.csr_matrix'>

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(
    max_iter=2000,
    n_jobs=-1,
    solver='liblinear',   # 稀疏矩阵推荐使用 liblinear 或 saga
)

lr.fit(X_train, y_train)
print("Training done.")
# Out:
# D:\Anaconda\envs\kaggle\lib\site-packages\sklearn\linear_model\_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
#   warnings.warn(
# Training done.

# %%
from sklearn.metrics import roc_auc_score

y_valid_prob = lr.predict_proba(X_valid)[:, 1]
auc = roc_auc_score(y_valid, y_valid_prob)
print("Baseline Logistic Regression AUC:", auc)
# Out:
# Baseline Logistic Regression AUC: 0.9103893339851603
